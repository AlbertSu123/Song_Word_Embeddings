# %%
import shutil 
from pathlib import Path 

firstfile = Path(r'C:\Users\alber\Desktop\lyrics\test2.txt') 
secondfile = Path(r'C:\Users\alber\Desktop\Scraper\test2.txt') 

newfile = "merged"
print("The merged content of the 2 files will be in", newfile) 

with open(newfile, "wb") as wfd: 
    for f in [firstfile, secondfile]: 
        with open(f, "rb") as fd: 
            shutil.copyfileobj(fd, wfd, 1024 * 1024 * 10) 

print("\nThe content is merged successfully.!")
# Out:
# The merged content of the 2 files will be in merged
#
# The content is merged successfully.!

# %%
for i in range(1958, 2019):
    firstfile = Path(r'C:\Users\alber\Desktop\lyrics\new_lyrics_' + str(i) + '.txt') 
    secondfile = Path(r'C:\Users\alber\Desktop\Scraper\new_lyrics_' + str(i) + '.txt')
    
    newfile = "merged" + str(i)
    with open(newfile, "wb") as wfd: 
        for f in [firstfile, secondfile]: 
            with open(f, "rb") as fd: 
                shutil.copyfileobj(fd, wfd, 1024 * 1024 * 10)
    print("\n was merged successfully" + str(i))
# Out:
#  was merged successfully1958
#
#  was merged successfully1959
#
#  was merged successfully1960
#
#  was merged successfully1961
#
#  was merged successfully1962
#
#  was merged successfully1963
#
#  was merged successfully1964
#
#  was merged successfully1965
#
#  was merged successfully1966
#
#  was merged successfully1967
#
#  was merged successfully1968
#
#  was merged successfully1969
#
#  was merged successfully1970
#
#  was merged successfully1971
#
#  was merged successfully1972
#
#  was merged successfully1973
#
#  was merged successfully1974
#
#  was merged successfully1975
#
#  was merged successfully1976
#
#  was merged successfully1977
#
#  was merged successfully1978
#
#  was merged successfully1979
#
#  was merged successfully1980
#
#  was merged successfully1981
#
#  was merged successfully1982
#
#  was merged successfully1983
#
#  was merged successfully1984
#
#  was merged successfully1985
#
#  was merged successfully1986
#
#  was merged successfully1987
#
# ...

# %%
for i in range(2019, 2020):
    firstfile = Path(r'C:\Users\alber\Desktop\lyrics\new_lyrics_' + str(i) + '.txt') 
    secondfile = Path(r'C:\Users\alber\Desktop\Scraper\new_lyrics_' + str(i) + '.txt')
    
    newfile = "merged" + str(i)
    with open(newfile, "wb") as wfd: 
        for f in [firstfile, secondfile]: 
            with open(f, "rb") as fd: 
                shutil.copyfileobj(fd, wfd, 1024 * 1024 * 10)
    print("\n was merged successfully" + str(i))
# Out:
#  was merged successfully2019
